# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline

# %% [markdown]
# ### Data Preprocessing

# %%
data = pd.read_excel("Assignment1_Dataset.xlsx")

# %%
data.head()
# Out:
#    Transaction date  House Age  Distance from nearest Metro station (km)  \
# 0       2012.916667       32.0                                  84.87882
# 1       2012.916667       19.5                                 306.59470
# 2       2013.583333       13.3                                 561.98450
# 3       2013.500000       13.3                                 561.98450
# 4       2012.833333        5.0                                 390.56840
#
#    Number of convenience stores  latitude  longitude  Number of bedrooms  \
# 0                            10  24.98298  121.54024                   1
# 1                             9  24.98034  121.53951                   2
# 2                             5  24.98746  121.54391                   3
# 3                             5  24.98746  121.54391                   2
# 4                             5  24.97937  121.54245                   1
#
#    House size (sqft)  House price of unit area
# ...

# %%
data.columns
# Out:
# Index(['Transaction date', 'House Age',
#        'Distance from nearest Metro station (km)',
#        'Number of convenience stores', 'latitude', 'longitude',
#        'Number of bedrooms', 'House size (sqft)', 'House price of unit area'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Transaction date   House Age  Distance from nearest Metro station (km)  \
# count        414.000000  414.000000                                414.000000
# mean        2013.148953   17.712560                               1083.885689
# std            0.281995   11.392485                               1262.109595
# min         2012.666667    0.000000                                 23.382840
# 25%         2012.916667    9.025000                                289.324800
# 50%         2013.166667   16.100000                                492.231300
# 75%         2013.416667   28.150000                               1454.279000
# max         2013.583333   43.800000                               6488.021000
#
#        Number of convenience stores    latitude   longitude  \
# count                    414.000000  414.000000  414.000000
# mean                       4.094203   24.969030  121.533361
# std                        2.945562    0.012410    0.015347
# ...

# %%
data.drop("Transaction date", axis='columns')
# Out:
#      House Age  Distance from nearest Metro station (km)  \
# 0         32.0                                  84.87882
# 1         19.5                                 306.59470
# 2         13.3                                 561.98450
# 3         13.3                                 561.98450
# 4          5.0                                 390.56840
# ..         ...                                       ...
# 409       13.7                                4082.01500
# 410        5.6                                  90.45606
# 411       18.8                                 390.96960
# 412        8.1                                 104.81010
# 413        6.5                                  90.45606
#
#      Number of convenience stores  latitude  longitude  Number of bedrooms  \
# 0                              10  24.98298  121.54024                   1
# 1                               9  24.98034  121.53951                   2
# ...

# %%
data.describe()
# Out:
#        Transaction date   House Age  Distance from nearest Metro station (km)  \
# count        414.000000  414.000000                                414.000000
# mean        2013.148953   17.712560                               1083.885689
# std            0.281995   11.392485                               1262.109595
# min         2012.666667    0.000000                                 23.382840
# 25%         2012.916667    9.025000                                289.324800
# 50%         2013.166667   16.100000                                492.231300
# 75%         2013.416667   28.150000                               1454.279000
# max         2013.583333   43.800000                               6488.021000
#
#        Number of convenience stores    latitude   longitude  \
# count                    414.000000  414.000000  414.000000
# mean                       4.094203   24.969030  121.533361
# std                        2.945562    0.012410    0.015347
# ...

# %%
#Correlation with output variable
cor = data.corr()
cor_target = abs(cor["House price of unit area"])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.5]
relevant_features
# Out:
# Distance from nearest Metro station (km)    0.673613
# Number of convenience stores                0.571005
# latitude                                    0.546307
# longitude                                   0.523287
# House price of unit area                    1.000000
# Name: House price of unit area, dtype: float64

# %% [markdown]
# ### Data Visualization

# %%
sns.set(rc = {'figure.figsize':(16,8)})
sns.heatmap(data.corr(), annot = True, fmt='.2g',cmap= 'coolwarm')
# Out:
# <AxesSubplot:>

# %%
data['Number of bedrooms'].value_counts().plot(kind='bar')
plt.title('Number of bedrooms')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.figure(figsize=(10,10))
sns.jointplot(x=data.latitude.values, y=data.longitude.values, size=10)
plt.ylabel('longitude', fontsize=12)
plt.xlabel('latitude', fontsize=12)
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
price = data.loc[:,"House price of unit area"]
size = data.loc[:,"House size (sqft)"]
plt.scatter(price,size)
plt.title("House price of unit area vs House size (sqft)")
# Out:
# Text(0.5, 1.0, 'House price of unit area vs House size (sqft)')

# %%
long = data.loc[:,"longitude"]
plt.scatter(price,long)
plt.title("Price vs Location of the area")
# Out:
# Text(0.5, 1.0, 'Price vs Location of the area')

# %%
lat = data.loc[:,"latitude"]
plt.scatter(price,lat)
plt.xlabel("Price")
plt.ylabel('Latitude')
plt.title("Latitude vs Price")
# Out:
# Text(0.5, 1.0, 'Latitude vs Price')

# %%
bedrooms = data.loc[:,"Number of bedrooms"]
plt.scatter(bedrooms,price)
plt.title("Bedroom and Price ")
plt.xlabel("Bedrooms")
plt.ylabel("Price")
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(data['Distance from nearest Metro station (km)'],data['House price of unit area'])
plt.title('Distance from nearest Metro station (km) vs Price')
# Out:
# Text(0.5, 1.0, 'Distance from nearest Metro station (km) vs Price')

# %%
plt.scatter(data['longitude'],data['House price of unit area'])
plt.title('location vs Price')
# Out:
# Text(0.5, 1.0, 'location vs Price')

# %% [markdown]
# ### LassoCV

# %%
x=data.drop("House price of unit area",axis=1)
y=data["House price of unit area"]

# %%
from sklearn.linear_model import LassoCV
reg = LassoCV()
reg.fit(x, y)
print("Best alpha using built-in LassoCV: %f" % reg.alpha_)
print("Best score using built-in LassoCV: %f" %reg.score(x,y))
coef = pd.Series(reg.coef_, index = x.columns)
# Out:
# Best alpha using built-in LassoCV: 11.539930
# Best score using built-in LassoCV: 0.486874

# %%
print("Lasso picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  str(sum(coef == 0)) + " variables")
# Out:
# Lasso picked 3 variables and eliminated the other 5 variables

# %%
imp_coef = coef.sort_values()

plt.rcParams['figure.figsize'] = (8.0, 10.0)
imp_coef.plot(kind = "barh")
plt.title("Feature importance using Lasso Model")
# Out:
# Text(0.5, 1.0, 'Feature importance using Lasso Model')

# %% [markdown]
# <b>As the number of features are less we have used lasso tool. The embedded method is also more feasible and accurate that the filter method.</b>
#
# So there are three feature that affect the price:
#
# 1.House size (sqft)
#
# 2.Distance from nearest Metro station (km)
#
# 3.House Age
#
# On top of it I will be adding the no.of convenieance store,latitude and longitude for understanding .

# %%
data=data.drop(['Transaction date','Number of bedrooms','Number of convenience stores'],axis=1)

# %%
data.head()
# Out:
#    House Age  Distance from nearest Metro station (km)  latitude  longitude  \
# 0       32.0                                  84.87882  24.98298  121.54024
# 1       19.5                                 306.59470  24.98034  121.53951
# 2       13.3                                 561.98450  24.98746  121.54391
# 3       13.3                                 561.98450  24.98746  121.54391
# 4        5.0                                 390.56840  24.97937  121.54245
#
#    House size (sqft)  House price of unit area
# 0                575                      37.9
# 1               1240                      42.2
# 2               1060                      47.3
# 3                875                      54.8
# 4                491                      43.1

# %%
x=data.drop("House price of unit area",axis=1)
y=data["House price of unit area"]

# %% [markdown]
# ### Prediction with help of Linear Regression

# %%
import sklearn
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.10,random_state =2)

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_test,y_test)
# Out:
# 0.5640903805008033

# %%
train_preds = reg.predict(x_train)
print("r2 of log distances:", sklearn.metrics.r2_score(y_train, train_preds))
print("r2 of distances: ", sklearn.metrics.r2_score(np.exp(y_train), np.exp(train_preds)))
# Out:
# r2 of log distances: 0.5246774040051456
# r2 of distances:  -0.0026954177897571263

# %%
test_preds = reg.predict(x_test)
print("r2 of log distances:", sklearn.metrics.r2_score(y_test, test_preds))
print("r2 of distances:", sklearn.metrics.r2_score(np.exp(y_test), np.exp(test_preds)))
# Out:
# r2 of log distances: 0.5640903805008033
# r2 of distances: -0.02727742007927092

# %%
print("RMSLE on log distances", np.sqrt(np.mean(np.square(np.log(test_preds+1.0) - np.log(y_test+1.0)))))
print("RMSLE on distances", np.sqrt(np.mean(np.square(np.log(np.exp(test_preds)+1.0) - np.log(np.exp(y_test)+1.0)))))
# Out:
# RMSLE on log distances 0.27213870005886254
# RMSLE on distances 7.927400832125665

# %% [markdown]
# ### Predicting with help of Gradient Boosting Regressor

# %%
from sklearn import ensemble
clf = ensemble.GradientBoostingRegressor(n_estimators = 400, max_depth = 5, min_samples_split = 2,
          learning_rate = 0.1, loss = 'ls')

# %%
clf.fit(x_train, y_train)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:286: FutureWarning: The loss 'ls' was deprecated in v1.0 and will be removed in version 1.2. Use 'squared_error' which is equivalent.
#   warnings.warn(
# GradientBoostingRegressor(loss='ls', max_depth=5, n_estimators=400)

# %%
clf.score(x_test,y_test)
# Out:
# 0.8272745389437617
